# %%
import requests
import pandas as pd
import re

# %%
url = "https://www.marvel.com/movies"
content = requests.get(url).text
pattern = "<p class=\"result-title\">.*?-->(.*?).*?-->"
matched = re.findall(pattern, content, re.S)
for m in matched:
    print(f"{m[1]}")
content
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8" class="next-head next-head"/><title class="next-head">Marvel Movies | Marvel Cinematic Universe (MCU) | Marvel Studios Films</title><meta name="title" content="Marvel Movies | Marvel Cinematic Universe (MCU) | Marvel Studios Films" class="next-head"/><meta property="og:site_name" content="Marvel Entertainment" class="next-head"/><meta name="twitter:creator" content="@Marvel" class="next-head"/><meta name="twitter:site" content="@Marvel" class="next-head"/><meta property="og:type" content="website" class="next-head"/><meta name="twitter:card" content="summary_large_image" class="next-head"/><meta name="description" content="Explore Marvel movies &amp; the Marvel Cinematic Universe (MCU) on the official site of Marvel Entertainment!\r\n" class="next-head"/><meta property="og:description" content="Explore Marvel movies &amp; the Marvel Cinematic Universe (MCU) on the official site of Marvel Entertainment!\r\n" class="next-head"
# ...
